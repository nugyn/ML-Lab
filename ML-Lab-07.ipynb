# %%
import pandas as pd
import numpy as np
import math

# %%
# Data set prep
sailData = pd.read_csv('s3://rmit-ml-2020s1-lab-data/symbolic/sailing-custom-python.tab',delim_whitespace=True)
zooData = pd.read_csv('s3://rmit-ml-2020s1-lab-data/symbolic/zoo-python.tab',delim_whitespace=True)
zooData = zooData.drop(columns='name')

# Dataframing
sailDataFrame = pd.DataFrame(sailData)
zooDataFrame = pd.DataFrame(zooData)

sailDataFrame.loc[sailDataFrame]
# Out:
#   Outlook Company Sailboat Sail
# 0   rainy     big      big  yes
# 1   rainy     big    small  yes
# 2   rainy     med      big   no
# 3   rainy     med    small   no
# 4   sunny     big      big  yes
#   hair feathers eggs milk airborne aquatic predator toothed backbone breathes  \
# 0  Yes       No   No  Yes       No      No      Yes     Yes      Yes      Yes
# 1  Yes       No   No  Yes       No      No       No     Yes      Yes      Yes
# 2   No       No  Yes   No       No     Yes      Yes     Yes      Yes       No
# 3  Yes       No   No  Yes       No      No      Yes     Yes      Yes      Yes
# 4  Yes       No   No  Yes       No      No      Yes     Yes      Yes      Yes
#
#   venomous fins  legs tail domestic catsize    type
# 0       No   No   4.0   No       No     Yes  mammal
# 1       No   No   4.0  Yes       No     Yes  mammal
# 2       No  Yes   0.0  Yes       No      No    fish
# 3       No   No   4.0   No       No     Yes  mammal
# 4       No   No   4.0  Yes       No     Yes  mammal

# %%
def entropy(zooDataFrame, target):
    entropy_value = 0
    for
# Out:
#   File "<ipython-input-4-83cdd1202233>", line 1
#     def entropy(data, target):
#                               ^
# SyntaxError: unexpected EOF while parsing
